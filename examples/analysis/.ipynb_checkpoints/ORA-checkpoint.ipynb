# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

# %%
sys.path.append('/Users/sheep/PyPathway/')

# %%
from pypathway.analysis.ora import Reactome, GO

# %%
test_set = ['Nsun3', 'Polrmt', 'Nlrx1', 'Sfxn5', 'Zc3h12c', 'Slc25a39', 'Arsg', 'Defb29', 'Ndufb6', 'Zfand1', 'Tmem77', '5730403B10Rik', 'RP23-195K8.6', 'Tlcd1', 'Psmc6', 'Slc30a6', 'LOC100047292', 'Lrrc40', 'Orc5l', 'Mpp7', 'Unc119b', 'Prkaca', 'Tcn2', 'Psmc3ip', 'Pcmtd2', 'Acaa1a', 'Lrrc1', '2810432D09Rik', 'Sephs2', 'Sac3d1', 'Tmlhe', 'LOC623451', 'Tsr2', 'Plekha7', 'Gys2', 'Arhgef12', 'Hibch', 'Lyrm2', 'Zbtb44', 'Entpd5', 'Rab11fip2', 'Lipt1', 'Intu', 'Anxa13', 'Klf12', 'Sat2', 'Gal3st2', 'Vamp8', 'Fkbpl', 'Aqp11', 'Trap1', 'Pmpcb', 'Tm7sf3', 'Rbm39', 'Bri3', 'Kdr', 'Zfp748', 'Nap1l1', 'Dhrs1', 'Lrrc56', 'Wdr20a', 'Stxbp2', 'Klf1', 'Ufc1', 'Ccdc16', '9230114K14Rik', 'Rwdd3', '2610528K11Rik', 'Aco1', 'Cables1', 'LOC100047214', 'Yars2', 'Lypla1', 'Kalrn', 'Gyk', 'Zfp787', 'Zfp655', 'Rabepk', 'Zfp650', '4732466D17Rik', 'Exosc4', 'Wdr42a', 'Gphn', '2610528J11Rik', '1110003E01Rik', 'Mdh1', '1200014M14Rik', 'AW209491', 'Mut', '1700123L14Rik', '2610036D13Rik', 'Cox15', 'Tmem30a', 'Nsmce4a', 'Tm2d2', 'Rhbdd3', 'Atxn2', 'Nfs1', '3110001I20Rik', 'BC038156', 'LOC100047782', '2410012H22Rik', 'Rilp', 'A230062G08Rik', 'Pttg1ip', 'Rab1', 'Afap1l1', 'Lyrm5', '2310026E23Rik', 'C330002I19Rik', 'Zfyve20', 'Poli', 'Tomm70a', 'Slc7a6os', 'Mat2b', '4932438A13Rik', 'Lrrc8a', 'Smo', 'Nupl2', 'Trpc2', 'Arsk', 'D630023B12Rik', 'Mtfr1', '5730414N17Rik', 'Scp2', 'Zrsr1', 'Nol7', 'C330018D20Rik', 'Ift122', 'LOC100046168', 'D730039F16Rik', 'Scyl1', '1700023B02Rik', '1700034H14Rik', 'Fbxo8', 'Paip1', 'Tmem186', 'Atpaf1', 'LOC100046254', 'LOC100047604', 'Coq10a', 'Fn3k', 'Sipa1l1', 'Slc25a16', 'Slc25a40', 'Rps6ka5', 'Trim37', 'Lrrc61', 'Abhd3', 'Gbe1', 'Parp16', 'Hsd3b2', 'Esm1', 'Dnajc18', 'Dolpp1', 'Lass2', 'Wdr34', 'Rfesd', 'Cacnb4', '2310042D19Rik', 'Srr', 'Bpnt1', '6530415H11Rik', 'Clcc1', 'Tfb1m', '4632404H12Rik', 'D4Bwg0951e', 'Med14', 'Adhfe1', 'Thtpa', 'Cat', 'Ell3', 'Akr7a5', 'Mtmr14', 'Timm44', 'Sf1', 'Ipp', 'Iah1', 'Trim23', 'Wdr89', 'Gstz1', 'Cradd', '2510006D16Rik', 'Fbxl6', 'LOC100044400', 'Zfp106', 'Cd55', '0610013E23Rik', 'Afmid', 'Tmem86a', 'Aldh6a1', 'Dalrd3', 'Smyd4', 'Nme7', 'Fars2', 'Tasp1', 'Cldn10', 'A930005H10Rik', 'Slc9a6', 'Adk', 'Rbks', '2210016F16Rik', 'Vwce', '4732435N03Rik', 'Zfp11', 'Vldlr', '9630013D21Rik', '4933407N01Rik', 'Fahd1', 'Mipol1', '1810019D21Rik', '1810049H13Rik', 'Tfam', 'Paics', '1110032A03Rik', 'LOC100044139', 'Dnajc19', 'BC016495', 'A930041I02Rik', 'Rqcd1', 'Usp34', 'Zcchc3', 'H2afj', 'Phf7', '4921508D12Rik', 'Kmo', 'Prpf18', 'Mcat', 'Txndc4', '4921530L18Rik', 'Vps13b', 'Scrn3', 'Tor1a', 'AI316807', 'Acbd4', 'Fah', 'Apool', 'Col4a4', 'Lrrc19', 'Gnmt', 'Nr3c1', 'Sip1', 'Ascc1', 'Fech', 'Abhd14a', 'Arhgap18', '2700046G09Rik', 'Yme1l1', 'Gk5', 'Glo1', 'Sbk1', 'Cisd1', '2210011C24Rik', 'Nxt2', 'Notum', 'Ankrd42', 'Ube2e1', 'Ndufv1', 'Slc33a1', 'Cep68', 'Rps6kb1', 'Hyi', 'Aldh1a3', 'Mynn', '3110048L19Rik', 'Rdh14', 'Proz', 'Gorasp1', 'LOC674449', 'Zfp775', '5430437P03Rik', 'Npy', 'Adh5', 'Sybl1', '4930432O21Rik', 'Nat9', 'LOC100048387', 'Mettl8', 'Eny2', '2410018G20Rik', 'Pgm2', 'Fgfr4', 'Mobkl2b', 'Atad3a', '4932432K03Rik', 'Dhtkd1', 'Ubox5', 'A530050D06Rik', 'Zdhhc5', 'Mgat1', 'Nudt6', 'Tpmt', 'Wbscr18', 'LOC100041586', 'Cdk5rap1', '4833426J09Rik', 'Myo6', 'Cpt1a', 'Gadd45gip1', 'Tmbim4', '2010309E21Rik', 'Asb9', '2610019F03Rik', '7530414M10Rik', 'Atp6v1b2', '2310068J16Rik', 'Ddt', 'Klhdc4', 'Hpn', 'Lifr', 'Ovol1', 'Nudt12', 'Cdan1', 'Fbxo9', 'Fbxl3', 'Hoxa7', 'Aldh8a1', '3110057O12Rik', 'Abhd11', 'Psmb1', 'ENSMUSG00000074286', 'Chpt1', 'Oxsm', '2310009A05Rik', '1700001L05Rik', 'Zfp148', '39509', 'Mrpl9', 'Tmem80', '9030420J04Rik', 'Naglu', 'Plscr2', 'Agbl3', 'Pex1', 'Cno', 'Neo1', 'Asf1a', 'Tnfsf5ip1', 'Pkig', 'AI931714', 'D130020L05Rik', 'Cntd1', 'Clec2h', 'Zkscan1', '1810044D09Rik', 'Mettl7a', 'Siae', 'Fbxo3', 'Fzd5', 'Tmem166', 'Tmed4', 'Gpr155', 'Rnf167', 'Sptlc1', 'Riok2', 'Tgds', 'Pms1', 'Pitpnc1', 'Pcsk7', '4933403G14Rik', 'Ei24', 'Crebl2', 'Tln1', 'Mrpl35', '2700038C09Rik', 'Ubie', 'Osgepl1', '2410166I05Rik', 'Wdr24', 'Ap4s1', 'Lrrc44', 'B3bp', 'Itfg1', 'Dmxl1', 'C1d']

# %%
len(test_set)
# Out:
# 375

# %%
# the input is a list of symbol
r = Reactome.run(['PIK3C2A', 'PTEN', 'UNC5B'])

# %%
r.table
# Out:
#                                                  name     dbId  found  \
# 0     Synthesis of PIPs at the late endosome membrane  9389426      3
# 1             Synthesis of PIPs at the Golgi membrane  9389428      3
# 2    Synthesis of PIPs at the early endosome membrane  9389430      3
# 3            Synthesis of PIPs at the plasma membrane  9388908      4
# 4                                       PI Metabolism  9388909      4
# 5     Synthesis of PIPs at the late endosome membrane  9741736      2
# 6             Synthesis of PIPs at the Golgi membrane  9741738      2
# 7    Synthesis of PIPs at the early endosome membrane  9741739      2
# 8                 Golgi Associated Vesicle Biogenesis  9389146      3
# 9                 trans-Golgi Network Vesicle Budding  9388994      3
# 10                   Clathrin derived vesicle budding  9388993      3
# 11                Regulation of PTEN mRNA translation  8943723      2
# 12                     TP53 Regulates Metabolic Genes  5628897      3
# 13           Synthesis of PIPs at the plasma membrane  9741266      2
# 14                                    PTEN Regulation  6807070      3
# 15                    PTEN Loss of Function in Cancer  5674404      1
# 16              Regulation of PTEN gene transcription  8943724      2
# 17           Synthesis of PIPs at the plasma membrane  1660499      2
# 18                    Regulation of PTEN localization  8948747      1
# 19                       PIP3 activates AKT signaling  1257604      3
# 20                                      PI Metabolism  1483255      2
# 21                                PI3K/AKT activation   198203      3
# 22                                   GAB1 signalosome   180292      3
# 23                  Netrin mediated repulsion signals   418886      1
# 24      Ligand-independent caspase activation via DCC   418889      1
# 25                            Interleukin-7 signaling  1266695      3
# 26    Synthesis of PIPs at the late endosome membrane  9316597      2
# 27            Synthesis of PIPs at the Golgi membrane  9316599      2
# 28   Synthesis of PIPs at the early endosome membrane  9316600      2
# 29                                      PI Metabolism  9316104      3
# ..                                                ...      ...    ...
# 70                            Phospholipid metabolism  9740788      2
# 71  Caspase activation via extrinsic apoptotic sig...  9388368      1
# 72                    Regulation of PTEN localization  9243237      1
# 73                    Regulation of PTEN localization  9642653      1
# 74           Synthesis of PIPs at the plasma membrane  9641893      2
# 75                                      PI Metabolism  9462668      2
# 76                    Regulation of PTEN localization  9578347      1
# 77           Synthesis of PIPs at the plasma membrane  9577589      2
# 78                    Regulation of PTEN localization  9177166      1
# 79           Synthesis of PIPs at the plasma membrane  9176392      2
# 80        Negative regulation of the PI3K/AKT network   199418      1
# 81                       PI3K/AKT Signaling in Cancer  2219528      1
# 82                           Downstream TCR signaling   202424      1
# 83                                      PI Metabolism  9641894      2
# 84                      Clathrin-mediated endocytosis  9316918      2
# 85                                      TCR signaling   202403      1
# 86          Regulation of PTEN stability and activity  9316885      1
# 87                                    PTEN Regulation  9316884      1
# 94  0.142030  0.261453         Mus musculus
# 95  0.261453  0.261453         Mus musculus
# 96  0.086963  0.261453         Mus musculus
# 97  0.085070  0.261453         Mus musculus
# 98  0.197239  0.261453         Mus musculus
# 99  0.194996  0.261453         Mus musculus
#
# [100 rows x 6 columns]

# %%
r.plot
# Out:
# <div id="box1498699669899673" style="width: 100%; height: 0px;background-color: #ffffff">
#     <script>
#         var box = $("#box1498699669899673");
#         var father = box.parent();
# //        var grandfather = father.parent();
#         var thirdfather = father.parent().parent().parent();
#         thirdfather.children(".prompt").remove();
#         father.parent().children(".prompt").remove();
#         father.css("max-width", "100%");
#         box.css("margin-left", "5px");
#         var target = document.getElementById("box1498699669899673");
# //        var w = target.offsetWidth;
#         var w = thirdfather.outerWidth();
#         console.log(w);
#         target.style.height = w * 0.6 + "px";
#         box.append($("<iframe width='" + (parseInt(w) - 15).toString() + "'" +
#                 " height='" + w * 0.6 + "' src='assets/plot/plot_1498699669899673.html' " +
#                 "frameborder='0'></iframe>"))
#     </script>
# </div>

# %%
r.overview
# Out:
# <bound method Reactome.overview of <pypathway.analysis.ora.Reactome object at 0x10a0b32b0>>

# %%
# simple test of Gene Ontology

# %%
path = '/Users/sheep/goatools/'
rg = GO.run(path + 'data/study', path + 'data/population', path + 'data/association',
        obo=path + 'go-basic.obo')
# Out:
# load obo file /Users/sheep/goatools/go-basic.obo
# /Users/sheep/goatools/go-basic.obo: fmt(1.2) rel(2017-04-21) 48,571 GO Terms
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# Propagating term counts to parents ..
# terms not found: {'GO:0022625', 'GO:0022627'}
# 31,855 out of 33,239 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#    269 out of    276 study items found in association
# Running multitest correction: local bonferroni
# Running multitest correction: local sidak
# Running multitest correction: local holm
#   797 GO terms are associated with 269 of 276 study items
#   6,120 GO terms are associated with 31,855 of 33,239 population items

# %%
rg.plot
# Out:
# <div id="box1498705481507017" style="width: 100%; height: 0px;background-color: #ffffff">
#     <script>
#         var box = $("#box1498705481507017");
#         var father = box.parent();
# //        var grandfather = father.parent();
#         var thirdfather = father.parent().parent().parent();
#         thirdfather.children(".prompt").remove();
#         father.parent().children(".prompt").remove();
#         father.css("max-width", "100%");
#         box.css("margin-left", "5px");
#         var target = document.getElementById("box1498705481507017");
# //        var w = target.offsetWidth;
#         var w = thirdfather.outerWidth();
#         console.log(w);
#         target.style.height = w * 0.6 + "px";
#         box.append($("<iframe width='" + (parseInt(w) - 15).toString() + "'" +
#                 " height='" + w * 0.6 + "' src='assets/plot/plot_1498705481507017.html' " +
#                 "frameborder='0'></iframe>"))
#     </script>
# </div>

# %%
rg.overview()
# Out:
# <div id="box1" style="width: 100%; height: 0px;background-color: #ffffff">
#     <script>
#         var box = $("#box1");
#         var father = box.parent();
#         var thirdfather = father.parent().parent().parent();
#         thirdfather.children(".prompt").remove();
#         father.parent().children(".prompt").remove();
#         father.css("max-width", "100%");
#         box.css("margin-left", "5px");
#         box.css("margin-top", "3px");
#         var target = document.getElementById("box1");
#         var w = thirdfather.outerWidth();
#         console.log(w);
#         target.style.height = w * 0.625 + "px";
#         box.append($("<iframe id='inner-iframe' width='" + (parseInt(w) - 15).toString() + "'" +
#                 " height='" + w * 0.625 + "' src=files/caches/cy_plot/index.html " +
#                 "frameborder='0'></iframe>"));
#         window.onresize = function () {
#             console.log("resize", thirdfather.outerWidth());
#             var inner_frame = $("#inner-iframe");
#             inner_frame.css("width", thirdfather.outerWidth() - 15 + "px");
#             inner_frame.css("height", thirdfather.outerWidth() * 0.625 + "px");
#             father.css("height", thirdfather.outerWidth() * 0.625 + 8 + "px");
#             thirdfather.css("height", thirdfather.outerWidth() * 0.625 + 8 + "px");
#             father.parent().css("height", thirdfather.outerWidth() * 0.625 + 8 + "px");
#         }
#     </script>
# </div>

# %%
rg.table
# Out:
#               GO  NS enrichment  \
# 0     GO:0036211  BP          e
# 1     GO:0006464  BP          e
# 2     GO:0006468  BP          e
# 3     GO:0016310  BP          e
# 4     GO:0043412  BP          e
# 5     GO:0019748  BP          e
# 6     GO:1901564  BP          e
# 7     GO:0009404  BP          e
# 8     GO:0009059  BP          p
# 9     GO:0044267  BP          e
# 10    GO:0006511  BP          e
# 11    GO:0043632  BP          e
# 12    GO:0019941  BP          e
# 13    GO:0034645  BP          p
# 14    GO:0019538  BP          e
# 15    GO:0051603  BP          e
# 16    GO:0006796  BP          e
# 17    GO:0006793  BP          e
# 18    GO:0019877  BP          e
# 19    GO:0044550  BP          e
# 20    GO:0044265  BP          e
# 21    GO:0072351  BP          e
# 22    GO:0030417  BP          e
# 23    GO:0030418  BP          e
# 24    GO:0006807  BP          e
# 25    GO:0044237  BP          e
# 26    GO:0006909  BP          e
# 27    GO:0051322  BP          e
# 28    GO:0006301  BP          e
# 29    GO:0009057  BP          e
# ...          ...  ..        ...
# 6092  GO:0045543  MF          p
# 6093  GO:0042277  MF          p
# 6094  GO:0000150  MF          p
# 6095  GO:0004392  MF          p
# 6096  GO:0016453  MF          p
# 6097  GO:0008483  MF          p
# 6098  GO:0043565  MF          p
# 6099  GO:0015101  MF          p
# 6100  GO:0016762  MF          p
# 6101  GO:0070405  MF          p
# 6102  GO:0005094  MF          p
# 6103  GO:0004601  MF          p
# 6104  GO:0030337  MF          p
# 6105  GO:0004076  MF          p
# 6106  GO:0047209  MF          p
# 6107  GO:0016166  MF          p
# 6108  GO:0046923  MF          p
# 6109  GO:0016454  MF          p
# 6110  GO:0016844  MF          p
# 6111  GO:0090079  MF          p
# 6112  GO:0008898  MF          p
# 6113  GO:0004595  MF          p
# 6114  GO:0070569  MF          p
# 6115  GO:0070704  MF          p
# 6116  GO:0008047  MF          p
# 6117  GO:0008641  MF          p
# 6118  GO:0031491  MF          p
# 6119  GO:0033799  MF          p
# 6120  GO:0032441  MF          p
# 6121  GO:0015140  MF          p
#
#                                                    name ratio_in_study  \
# 0                          protein modification process         33/276
# 1                 cellular protein modification process         33/276
# 2                               protein phosphorylation         22/276
# 3                                       phosphorylation         22/276
# 4                            macromolecule modification         33/276
# 5                           secondary metabolic process          9/276
# 6             organonitrogen compound metabolic process         52/276
# 7                               toxin metabolic process          5/276
# 8                    macromolecule biosynthetic process          1/276
# 9                    cellular protein metabolic process         35/276
# 10        ubiquitin-dependent protein catabolic process          9/276
# 11    modification-dependent macromolecule catabolic...          9/276
# 12     modification-dependent protein catabolic process          9/276
# 13          cellular macromolecule biosynthetic process          1/276
# 14                            protein metabolic process         42/276
# 15    proteolysis involved in cellular protein catab...          9/276
# 16      phosphate-containing compound metabolic process         25/276
# 17                         phosphorus metabolic process         25/276
# 18                 diaminopimelate biosynthetic process          2/276
# 19            secondary metabolite biosynthetic process          6/276
# 20             cellular macromolecule catabolic process          9/276
# 21              tricarboxylic acid biosynthetic process          2/276
# 22                      nicotianamine metabolic process          2/276
# 23                   nicotianamine biosynthetic process          2/276
# 24                  nitrogen compound metabolic process         58/276
# 25                           cellular metabolic process         71/276
# 26                                         phagocytosis          2/276
# 27                                             anaphase          2/276
# 28                               postreplication repair          2/276
# 29                      macromolecule catabolic process          9/276
# ...                                                 ...            ...
# 6092            gibberellin 2-beta-dioxygenase activity          0/276
# 6093                                    peptide binding          0/276
# 6094                               recombinase activity          0/276
# 6095              heme oxygenase (decyclizing) activity          0/276
# 6096                       C-acetyltransferase activity          0/276
# 6097                              transaminase activity          0/276
# 6098                      sequence-specific DNA binding          0/276
# 6099  organic cation transmembrane transporter activity          0/276
# 6100       xyloglucan:xyloglucosyl transferase activity          0/276
# 6101                               ammonium ion binding          0/276
# 6102            Rho GDP-dissociation inhibitor activity          0/276
# 6103                                peroxidase activity          0/276
# 6104        DNA polymerase processivity factor activity          0/276
# 6105                           biotin synthase activity          0/276
# 6106     coniferyl-alcohol glucosyltransferase activity          0/276
# 6107                    phytoene dehydrogenase activity          0/276
# 6108                      ER retention sequence binding          0/276
# 6109                    C-palmitoyltransferase activity          0/276
# 6110                    strictosidine synthase activity          0/276
# 6111  translation regulator activity, nucleic acid b...          0/276
# 6112  S-adenosylmethionine-homocysteine S-methyltran...          0/276
# 6113  pantetheine-phosphate adenylyltransferase acti...          0/276
# 6114                       uridylyltransferase activity          0/276
# 6115                         sterol desaturase activity          0/276
# 6116                          enzyme activator activity          0/276
# 6117           small protein activating enzyme activity          0/276
# 6118                                 nucleosome binding          0/276
# 6119          myricetin 3'-O-methyltransferase activity          0/276
# 6120                  pheophorbide a oxygenase activity          0/276
# 6121          malate transmembrane transporter activity          0/276
#
#      ratio_in_pop  p_uncorrected depth  study_count  p_bonferroni  p_sidak  \
# 0      1727/33239       0.000008  n.a.           33        0.0505   0.0492
# 1      1727/33239       0.000008  n.a.           33        0.0505   0.0492
# 2       922/33239       0.000011  n.a.           22        0.0660   0.0643
# 3       996/33239       0.000035  n.a.           22        0.2130   0.2070
# 4      1877/33239       0.000057  n.a.           33        0.3510   0.3420
# 5       208/33239       0.000066  n.a.            9        0.4040   0.3940
# 6      3612/33239       0.000085  n.a.           52        0.5210   0.5080
# 6116     75/33239       1.000000  n.a.            0        1.0000   1.0000
# 6117     12/33239       1.000000  n.a.            0        1.0000   1.0000
# 6118      3/33239       1.000000  n.a.            0        1.0000   1.0000
# 6119      1/33239       1.000000  n.a.            0        1.0000   1.0000
# 6120      1/33239       1.000000  n.a.            0        1.0000   1.0000
# 6121      5/33239       1.000000  n.a.            0        1.0000   1.0000
#
#       p_holm
# 0     0.0505
# 1     0.0505
# 2     0.0660
# 3     0.2120
# 4     0.3510
# 5     0.4030
# 6     0.5200
# 7     0.6280
# 8     0.8200
# 9     1.0000
# 10    1.0000
# 11    1.0000
# 12    1.0000
# 13    1.0000
# 14    1.0000
# 15    1.0000
# 16    1.0000
# 17    1.0000
# 18    1.0000
# 19    1.0000
# 20    1.0000
# 21    1.0000
# 22    1.0000
# 23    1.0000
# 24    1.0000
# 25    1.0000
# 26    1.0000
# 27    1.0000
# 28    1.0000
# 29    1.0000
# ...      ...
# 6092  1.0000
# 6093  1.0000
# 6094  1.0000
# 6095  1.0000
# 6096  1.0000
# 6097  1.0000
# 6098  1.0000
# 6099  1.0000
# 6100  1.0000
# 6101  1.0000
# 6102  1.0000
# 6103  1.0000
# 6104  1.0000
# 6105  1.0000
# 6106  1.0000
# 6107  1.0000
# 6108  1.0000
# 6109  1.0000
# 6110  1.0000
# 6111  1.0000
# 6112  1.0000
# 6113  1.0000
# 6114  1.0000
# 6115  1.0000
# 6116  1.0000
# 6117  1.0000
# 6118  1.0000
# 6119  1.0000
# 6120  1.0000
# 6121  1.0000
#
# [6122 rows x 12 columns]

# %%
from goatools.obo_parser import GODag

# %%
g = GODag('/Users/sheep/goatools/go-basic.obo')
# Out:
# load obo file /Users/sheep/goatools/go-basic.obo
# /Users/sheep/goatools/go-basic.obo: fmt(1.2) rel(2017-04-21) 48,571 GO Terms

# %%
t = g['GO:0009507']

# %%
rg.overview(g)
# Out:
# <div id="box1" style="width: 100%; height: 0px;background-color: #ffffff">
#     <script>
#         var box = $("#box1");
#         var father = box.parent();
#         var thirdfather = father.parent().parent().parent();
#         thirdfather.children(".prompt").remove();
#         father.parent().children(".prompt").remove();
#         father.css("max-width", "100%");
#         box.css("margin-left", "5px");
#         box.css("margin-top", "3px");
#         var target = document.getElementById("box1");
#         var w = thirdfather.outerWidth();
#         console.log(w);
#         target.style.height = w * 0.625 + "px";
#         box.append($("<iframe id='inner-iframe' width='" + (parseInt(w) - 15).toString() + "'" +
#                 " height='" + w * 0.625 + "' src=files/caches/cy_plot/index.html " +
#                 "frameborder='0'></iframe>"));
#         window.onresize = function () {
#             console.log("resize", thirdfather.outerWidth());
#             var inner_frame = $("#inner-iframe");
#             inner_frame.css("width", thirdfather.outerWidth() - 15 + "px");
#             inner_frame.css("height", thirdfather.outerWidth() * 0.625 + "px");
#             father.css("height", thirdfather.outerWidth() * 0.625 + 8 + "px");
#             thirdfather.css("height", thirdfather.outerWidth() * 0.625 + 8 + "px");
#             father.parent().css("height", thirdfather.outerWidth() * 0.625 + 8 + "px");
#         }
#     </script>
# </div>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

# %%
sys.path.append('/Users/sheep/PyPathway/')

# %%
from pypathway.analysis.gsea import Enrichr

# %%
data = '''ADAM10,0.180332
ADAM12,0.145189
ADAMTS10,0.168047
ARHGAP1,0.138820
ARHGAP28,0.158224
ARSE,0.143072
ASAM,0.145892
ATP13A4,0.153650
BMP1,0.144291
BMP7,0.157614
BNC2,0.147440
BRDT,0.154325
BTN1A1,0.147376
C12ORF53,0.155081
C1QTNF6,0.159286
C20ORF58,0.255140
C3ORF59,0.162077
C4ORF26,0.208984
C6ORF65,0.159860
C7ORF10,0.169436
C8B,0.161250
C9ORF53,0.153146
CCDC36,0.181141
CCR6,0.200862
CD59,0.137231
CDKL1,0.139624
CETN2,0.143746
CHRNA3,0.165085
CILP2,0.170691
CNTN1,0.168352
CNTN6,0.189580
COL16A1,0.137049
COL6A1,0.147329
COPZ2,0.145576
CORIN,0.148437
CPB2,0.197561
CSMD1,0.163244
CX3CR1,0.143887
CYP27C1,0.158658
DEPDC7,0.141172
F8A1,0.162165
FAM127A,0.155750
FAM127B,0.141131
FAM26E,0.146965
FAM77D,0.153985
FAM7A1,0.173928
FASN,0.159943
FBLN1,0.178655
FKBP10,0.138075
FKBP5,0.144719
FKBP7,0.138163
FLJ14213,0.183944
FLRT2,0.152835
FST,0.191298
GAS7,0.143365
GLI2,0.137430
GLIS1,0.217921
GPR1,0.206099
GPR32,0.224969
HMCN1,0.156594
HS3ST3A1,0.137776
IGF2AS,0.164921
IGFBP6,0.146842
IGFL2,0.141019
IL13RA1,0.156600
KCNMB4,0.145863
KERA,0.172826
KIAA0574,0.159286
KIAA1217,0.142403
KIF26B,0.146848
KIRREL,0.142655
L1TD1,0.165754
LEPRE1,0.136826
LIPC,0.163144
LL22NC03-75B3.6,0.149440
LOC554202,0.199848
LOXL2,0.143898
LRRC15,0.152020
MN1,0.164264
MYL3,0.171155
MYO1H,0.142497
NALCN,0.137905
NEGR1,0.143324
NETO1,0.188078
NPFFR2,0.144467
NRG1,0.153205
NSDHL,0.153134
NUAK1,0.162089
ODZ4,0.140169
OR6M1,0.141084
OSTALPHA,0.182308
PANX3,0.185850
PBEF1,0.151393
PCOLCE,0.144854
PCSK9,0.154917
PDLIM2,0.171325
PEBP4,0.145968
PPAPDC3,0.142040
PPP1R2,0.176913
PPP1R2P3,0.139823
PROL1,0.239401
PTHR1,0.224412
PTPRD,0.153310
PTPRN,0.171594
RAB5C,0.143887
RASGRF2,0.207916
RBP2,0.228734
SALL1,0.151457
SCN2B,0.170017
SELPLG,0.148021
SEMA3D,0.163050
SLAMF9,0.139618
SLC10A3,0.156758
SLC16A12,0.214209
SLC24A2,0.156776
SLC38A4,0.144239
SLC38A5,0.159145
SPARC,0.137295
ST6GAL2,0.147036
ST7L,0.170123
STAT5A,0.154389
STGC3,0.161960
THBS2,0.138756
TLL2,0.140333
TLOC1,0.138627
TMEM106A,0.174978
TNFSF11,0.154677
TRIM59,0.154548
UPK3A,0.138345
WISP1,0.147347
ZFPM2,0.155644
ZMAT3,0.148390
ZNF689,0.144913'''

# %%
d = {x.split(',')[0]: x.split(',')[1] for x in data.split('\n') if x}

# %%
d
# Out:
# {'ADAM10': '0.180332',
#  'ADAM12': '0.145189',
#  'ADAMTS10': '0.168047',
#  'ARHGAP1': '0.138820',
#  'ARHGAP28': '0.158224',
#  'ARSE': '0.143072',
#  'ASAM': '0.145892',
#  'ATP13A4': '0.153650',
#  'BMP1': '0.144291',
#  'BMP7': '0.157614',
#  'BNC2': '0.147440',
#  'BRDT': '0.154325',
#  'BTN1A1': '0.147376',
#  'C12ORF53': '0.155081',
#  'C1QTNF6': '0.159286',
#  'C20ORF58': '0.255140',
#  'C3ORF59': '0.162077',
#  'C4ORF26': '0.208984',
#  'C6ORF65': '0.159860',
#  'C7ORF10': '0.169436',
#  'C8B': '0.161250',
#  'C9ORF53': '0.153146',
#  'CCDC36': '0.181141',
#  'CCR6': '0.200862',
#  'CD59': '0.137231',
#  'CDKL1': '0.139624',
#  'CETN2': '0.143746',
#  'CHRNA3': '0.165085',
#  'CILP2': '0.170691',
#  'CNTN1': '0.168352',
#  'CNTN6': '0.189580',
#  'COL16A1': '0.137049',
#  'COL6A1': '0.147329',
#  'COPZ2': '0.145576',
#  'CORIN': '0.148437',
#  'CPB2': '0.197561',
#  'CSMD1': '0.163244',
#  'CX3CR1': '0.143887',
#  'CYP27C1': '0.158658',
#  'DEPDC7': '0.141172',
#  'F8A1': '0.162165',
#  'FAM127A': '0.155750',
#  'FAM127B': '0.141131',
#  'FAM26E': '0.146965',
#  'FAM77D': '0.153985',
#  'FAM7A1': '0.173928',
#  'FASN': '0.159943',
#  'FBLN1': '0.178655',
#  'FKBP10': '0.138075',
#  'FKBP5': '0.144719',
#  'FKBP7': '0.138163',
#  'FLJ14213': '0.183944',
#  'FLRT2': '0.152835',
#  'FST': '0.191298',
#  'GAS7': '0.143365',
#  'GLI2': '0.137430',
#  'GLIS1': '0.217921',
#  'GPR1': '0.206099',
#  'GPR32': '0.224969',
#  'HMCN1': '0.156594',
#  'HS3ST3A1': '0.137776',
#  'IGF2AS': '0.164921',
#  'IGFBP6': '0.146842',
#  'IGFL2': '0.141019',
#  'IL13RA1': '0.156600',
#  'KCNMB4': '0.145863',
#  'KERA': '0.172826',
#  'KIAA0574': '0.159286',
#  'KIAA1217': '0.142403',
#  'KIF26B': '0.146848',
#  'KIRREL': '0.142655',
#  'L1TD1': '0.165754',
#  'LEPRE1': '0.136826',
#  'LIPC': '0.163144',
#  'LL22NC03-75B3.6': '0.149440',
#  'LOC554202': '0.199848',
#  'LOXL2': '0.143898',
#  'LRRC15': '0.152020',
#  'MN1': '0.164264',
#  'MYL3': '0.171155',
#  'MYO1H': '0.142497',
#  'NALCN': '0.137905',
#  'NEGR1': '0.143324',
#  'NETO1': '0.188078',
#  'NPFFR2': '0.144467',
#  'NRG1': '0.153205',
#  'NSDHL': '0.153134',
#  'NUAK1': '0.162089',
#  'ODZ4': '0.140169',
#  'OR6M1': '0.141084',
#  'OSTALPHA': '0.182308',
#  'PANX3': '0.185850',
#  'PBEF1': '0.151393',
#  'PCOLCE': '0.144854',
#  'PCSK9': '0.154917',
#  'PDLIM2': '0.171325',
#  'PEBP4': '0.145968',
#  'PPAPDC3': '0.142040',
#  'PPP1R2': '0.176913',
#  'PPP1R2P3': '0.139823',
#  'PROL1': '0.239401',
#  'PTHR1': '0.224412',
#  'PTPRD': '0.153310',
#  'PTPRN': '0.171594',
#  'RAB5C': '0.143887',
#  'RASGRF2': '0.207916',
#  'RBP2': '0.228734',
#  'SALL1': '0.151457',
#  'SCN2B': '0.170017',
#  'SELPLG': '0.148021',
#  'SEMA3D': '0.163050',
#  'SLAMF9': '0.139618',
#  'SLC10A3': '0.156758',
#  'SLC16A12': '0.214209',
#  'SLC24A2': '0.156776',
#  'SLC38A4': '0.144239',
#  'SLC38A5': '0.159145',
#  'SPARC': '0.137295',
#  'ST6GAL2': '0.147036',
#  'ST7L': '0.170123',
#  'STAT5A': '0.154389',
#  'STGC3': '0.161960',
#  'THBS2': '0.138756',
#  'TLL2': '0.140333',
#  'TLOC1': '0.138627',
#  'TMEM106A': '0.174978',
#  'TNFSF11': '0.154677',
#  'TRIM59': '0.154548',
#  'UPK3A': '0.138345',
#  'WISP1': '0.147347',
#  'ZFPM2': '0.155644',
#  'ZMAT3': '0.148390',
#  'ZNF689': '0.144913'}

# %%
d2 = [x for x in data.split('\n') if x]

# %%
d2
# Out:
# ['ADAM10,0.180332',
#  'ADAM12,0.145189',
#  'ADAMTS10,0.168047',
#  'ARHGAP1,0.138820',
#  'ARHGAP28,0.158224',
#  'ARSE,0.143072',
#  'ASAM,0.145892',
#  'ATP13A4,0.153650',
#  'BMP1,0.144291',
#  'BMP7,0.157614',
#  'BNC2,0.147440',
#  'BRDT,0.154325',
#  'BTN1A1,0.147376',
#  'C12ORF53,0.155081',
#  'C1QTNF6,0.159286',
#  'C20ORF58,0.255140',
#  'C3ORF59,0.162077',
#  'C4ORF26,0.208984',
#  'C6ORF65,0.159860',
#  'C7ORF10,0.169436',
#  'C8B,0.161250',
#  'C9ORF53,0.153146',
#  'CCDC36,0.181141',
#  'CCR6,0.200862',
#  'CD59,0.137231',
#  'CDKL1,0.139624',
#  'CETN2,0.143746',
#  'CHRNA3,0.165085',
#  'CILP2,0.170691',
#  'CNTN1,0.168352',
#  'CNTN6,0.189580',
#  'COL16A1,0.137049',
#  'COL6A1,0.147329',
#  'COPZ2,0.145576',
#  'CORIN,0.148437',
#  'CPB2,0.197561',
#  'CSMD1,0.163244',
#  'CX3CR1,0.143887',
#  'CYP27C1,0.158658',
#  'DEPDC7,0.141172',
#  'F8A1,0.162165',
#  'FAM127A,0.155750',
#  'FAM127B,0.141131',
#  'FAM26E,0.146965',
#  'FAM77D,0.153985',
#  'FAM7A1,0.173928',
#  'FASN,0.159943',
#  'FBLN1,0.178655',
#  'FKBP10,0.138075',
#  'FKBP5,0.144719',
#  'FKBP7,0.138163',
#  'FLJ14213,0.183944',
#  'FLRT2,0.152835',
#  'FST,0.191298',
#  'GAS7,0.143365',
#  'GLI2,0.137430',
#  'GLIS1,0.217921',
#  'GPR1,0.206099',
#  'GPR32,0.224969',
#  'HMCN1,0.156594',
#  'HS3ST3A1,0.137776',
#  'IGF2AS,0.164921',
#  'IGFBP6,0.146842',
#  'IGFL2,0.141019',
#  'IL13RA1,0.156600',
#  'KCNMB4,0.145863',
#  'KERA,0.172826',
#  'KIAA0574,0.159286',
#  'KIAA1217,0.142403',
#  'KIF26B,0.146848',
#  'KIRREL,0.142655',
#  'L1TD1,0.165754',
#  'LEPRE1,0.136826',
#  'LIPC,0.163144',
#  'LL22NC03-75B3.6,0.149440',
#  'LOC554202,0.199848',
#  'LOXL2,0.143898',
#  'LRRC15,0.152020',
#  'MN1,0.164264',
#  'MYL3,0.171155',
#  'MYO1H,0.142497',
#  'NALCN,0.137905',
#  'NEGR1,0.143324',
#  'NETO1,0.188078',
#  'NPFFR2,0.144467',
#  'NRG1,0.153205',
#  'NSDHL,0.153134',
#  'NUAK1,0.162089',
#  'ODZ4,0.140169',
#  'OR6M1,0.141084',
#  'OSTALPHA,0.182308',
#  'PANX3,0.185850',
#  'PBEF1,0.151393',
#  'PCOLCE,0.144854',
#  'PCSK9,0.154917',
#  'PDLIM2,0.171325',
#  'PEBP4,0.145968',
#  'PPAPDC3,0.142040',
#  'PPP1R2,0.176913',
#  'PPP1R2P3,0.139823',
#  'PROL1,0.239401',
#  'PTHR1,0.224412',
#  'PTPRD,0.153310',
#  'PTPRN,0.171594',
#  'RAB5C,0.143887',
#  'RASGRF2,0.207916',
#  'RBP2,0.228734',
#  'SALL1,0.151457',
#  'SCN2B,0.170017',
#  'SELPLG,0.148021',
#  'SEMA3D,0.163050',
#  'SLAMF9,0.139618',
#  'SLC10A3,0.156758',
#  'SLC16A12,0.214209',
#  'SLC24A2,0.156776',
#  'SLC38A4,0.144239',
#  'SLC38A5,0.159145',
#  'SPARC,0.137295',
#  'ST6GAL2,0.147036',
#  'ST7L,0.170123',
#  'STAT5A,0.154389',
#  'STGC3,0.161960',
#  'THBS2,0.138756',
#  'TLL2,0.140333',
#  'TLOC1,0.138627',
#  'TMEM106A,0.174978',
#  'TNFSF11,0.154677',
#  'TRIM59,0.154548',
#  'UPK3A,0.138345',
#  'WISP1,0.147347',
#  'ZFPM2,0.155644',
#  'ZMAT3,0.148390',
#  'ZNF689,0.144913']

# %%
r = Enrichr.run(d2, database='Reactome')

# %%
r.plot
# Out:
# <div id="box1498705744613385" style="width: 100%; height: 0px;background-color: #ffffff">
#     <script>
#         var box = $("#box1498705744613385");
#         var father = box.parent();
# //        var grandfather = father.parent();
#         var thirdfather = father.parent().parent().parent();
#         thirdfather.children(".prompt").remove();
#         father.parent().children(".prompt").remove();
#         father.css("max-width", "100%");
#         box.css("margin-left", "5px");
#         var target = document.getElementById("box1498705744613385");
# //        var w = target.offsetWidth;
#         var w = thirdfather.outerWidth();
#         console.log(w);
#         target.style.height = w * 0.6 + "px";
#         box.append($("<iframe width='" + (parseInt(w) - 15).toString() + "'" +
#                 " height='" + w * 0.6 + "' src='assets/plot/plot_1498705744613385.html' " +
#                 "frameborder='0'></iframe>"))
#     </script>
# </div>

# %%
r.table
# Out:
#                                                   Term  Overlap   P-value  \
# 0    Crosslinking of collagen fibrils_Homo sapiens_...      4/9  0.001533
# 1    Extracellular matrix organization_Homo sapiens...   10/283  0.011713
# 2    Assembly of collagen fibrils and other multime...     5/54  0.005568
# 3    Collagen biosynthesis and modifying enzymes_Ho...     5/63  0.008538
# 4        Collagen formation_Homo sapiens_R-HSA-1474290     6/85  0.019114
# 5    Elastic fibre formation_Homo sapiens_R-HSA-156...     3/41  0.030395
# 6           Rho GTPase cycle_Homo sapiens_R-HSA-194840    4/122  0.047949
# 7    Diseases of glycosylation_Homo sapiens_R-HSA-3...     3/88  0.116294
# 8    Defective CHST6 causes MCDC1_Homo sapiens_R-HS...      1/7  0.045638
# 9         L1CAM interactions_Homo sapiens_R-HSA-373760     3/96  0.133991
# 10   Transport of inorganic cations/anions and amin...     3/99  0.140777
# 11   Degradation of the extracellular matrix_Homo s...    4/106  0.156883
# 12   Neurofascin interactions_Homo sapiens_R-HSA-44...      1/7  0.045638
# 13   Highly calcium permeable postsynaptic nicotini...     1/11  0.070783
# 14   Sodium/Calcium exchangers_Homo sapiens_R-HSA-4...     1/11  0.070783
# 15   Highly sodium permeable acetylcholine nicotini...      1/7  0.045638
# 16   GLI proteins bind promoters of Hh responsive g...      1/7  0.045638
# 17   Constitutive Signaling by NOTCH1 HD Domain Mut...     1/15  0.095270
# 18   Signaling by NOTCH1 t(7;9)(NOTCH1:M1580_K2555)...      1/7  0.045638
# 19             Axon guidance_Homo sapiens_R-HSA-422475    7/515  0.258627
# 20   The activation of arylsulfatases_Homo sapiens_...     1/13  0.083107
# 21   Activation of Nicotinic Acetylcholine Receptor...     1/14  0.089209
# 22   Signaling by NOTCH1 HD Domain Mutants in Cance...     1/15  0.095270
# 23   Acetylcholine Binding And Downstream Events_Ho...     1/14  0.089209
# 24   Presynaptic nicotinic acetylcholine receptors_...     1/12  0.076965
# 25   Receptor-ligand binding initiates the second p...     1/14  0.089209
# 26   ERBB2 Activates PTK6 Signaling_Homo sapiens_R-...     1/13  0.083107
# 27   POU5F1 (OCT4), SOX2, NANOG activate genes rela...     1/13  0.083107
# 28   Downregulation of ERBB2:ERBB3 signaling_Homo s...     1/13  0.083107
# 29         CHL1 interactions_Homo sapiens_R-HSA-447041      1/9  0.058294
# ..                                                 ...      ...       ...
# 266                DNA Repair_Homo sapiens_R-HSA-73894    1/285  0.852696
# 267   Metabolism of proteins_Homo sapiens_R-HSA-392499   9/1074  0.847834
# 268  Signaling by Insulin receptor_Homo sapiens_R-H...    2/311  0.876481
# 269    VEGFA-VEGFR2 Pathway_Homo sapiens_R-HSA-4420097    2/320  0.883792
# 270  Organelle biogenesis and maintenance_Homo sapi...    1/326  0.888426
# 271      Signal Transduction_Homo sapiens_R-HSA-162582  20/2465  0.849431
# 272        Signaling by VEGF_Homo sapiens_R-HSA-194138    2/328  0.889930
# 273  Downstream signaling of activated FGFR2_Homo s...    2/329  0.890674
# 274      Signaling by FGFR3_Homo sapiens_R-HSA-5654741    2/333  0.893601
# 275      Signaling by FGFR4_Homo sapiens_R-HSA-5654743    2/332  0.892876
# 276  Downstream signaling of activated FGFR3_Homo s...    2/329  0.890674
# 277  Generic Transcription Pathway_Homo sapiens_R-H...    2/812  0.996039
# 278              Metabolism_Homo sapiens_R-HSA-1430728   8/1908  0.996675
# 279  Adaptive Immune System_Homo sapiens_R-HSA-1280218    1/762  0.994393
# 280           Gene Expression_Homo sapiens_R-HSA-74160   2/1631  0.999988
# 281         DAP12 signaling_Homo sapiens_R-HSA-2424491    2/344  0.901255
# 282  Downstream signaling of activated FGFR4_Homo s...    2/329  0.890674
# 283              Cell Cycle_Homo sapiens_R-HSA-1640170    1/566  0.978313
# 284  NGF signalling via TRKA from the plasma membra...    2/374  0.919464
# 285            Immune System_Homo sapiens_R-HSA-168256   7/1547  0.979817
# 286  Transcriptional Regulation by TP53_Homo sapien...    1/348  0.903901
# 287      DAP12 interactions_Homo sapiens_R-HSA-2172127    2/359  0.910820
# 288      Signaling by FGFR2_Homo sapiens_R-HSA-5654738    2/361  0.912023
# 289        Signalling by NGF_Homo sapiens_R-HSA-166520    2/450  0.952013
# 290  Fc epsilon receptor (FCERI) signaling_Homo sap...    2/395  0.930186
# 291  GPCR downstream signaling_Homo sapiens_R-HSA-3...    5/983  0.897365
# 292       Cell Cycle, Mitotic_Homo sapiens_R-HSA-69278    1/462  0.955788
# 293        Signaling by GPCR_Homo sapiens_R-HSA-372790   7/1293  0.936763
# 294  Olfactory Signaling Pathway_Homo sapiens_R-HSA...    1/418  0.940309
# 295     Innate Immune System_Homo sapiens_R-HSA-168249    5/807  0.908348
#
#      Adjusted P-value  Old P-value  Old Adjusted P-value   Z-score  \
# 0            0.453625     0.002527              0.670540 -2.198192
# 1            0.609294     0.014997              0.670540 -2.087576
# 2            0.609294     0.007231              0.670540 -2.025287
# 3            0.609294     0.010819              0.670540 -2.002621
# 4            0.609294     0.023296              0.670540 -1.991778
# 5            0.609294     0.035973              0.670540 -1.911626
# 6            0.609294     0.056366              0.670540 -1.678180
# 7            0.614699     0.129952              0.678775 -1.416361
# 8            0.609294     0.054455              0.670540 -1.207774
# 9            0.652109     0.149008              0.711395 -1.380533
# 10           0.658315     0.156297              0.720564 -1.395470
# 11           0.673846     0.173559              0.732394 -1.425234
# 12           0.609294     0.054455              0.670540 -1.087991
# 13           0.609294     0.080578              0.670540 -1.065998
# 14           0.609294     0.080578              0.670540 -1.057735
# 15           0.609294     0.054455              0.670540 -1.013454
# 16           0.609294     0.054455              0.670540 -0.996331
# 17           0.609294     0.105990              0.670540 -0.991133
# 18           0.609294     0.054455              0.670540 -0.984696
# 19           0.718180     0.295924              0.796304 -1.451155
# 20           0.609294     0.093371              0.670540 -0.966824
# 21           0.609294     0.099702              0.670540 -0.962266
# 22           0.609294     0.105990              0.670540 -0.958442
# 23           0.609294     0.099702              0.670540 -0.948689
# 24           0.609294     0.086996              0.670540 -0.947175
# 25           0.609294     0.099702              0.670540 -0.944264
# 26           0.609294     0.093371              0.670540 -0.936576
# 27           0.609294     0.093371              0.670540 -0.930028
# 28           0.609294     0.093371              0.670540 -0.922069
# 29           0.609294     0.067606              0.670540 -0.919398
# ..                ...          ...                   ...       ...
# 266          0.942613     0.869105              0.967070 -0.097694
# 267          0.942613     0.886122              0.967070 -0.080613
# 268          0.950560     0.891554              0.967070 -0.072381
# 269          0.950560     0.898406              0.967070 -0.044920
# 270          0.950560     0.902734              0.967070 -0.035101
# 271          0.942613     0.915485              0.967070 -0.029426
# 272          0.950560     0.904137              0.967070 -0.021733
# 273          0.950560     0.904830              0.967070 -0.009774
# 274          0.950560     0.907556              0.967070 -0.007348
# 275          0.950560     0.906882              0.967070 -0.001385
# 276          0.950560     0.904830              0.967070 -0.000699
# 277          0.999988     0.997423              0.999997  0.123995
# 278          0.999988     0.998788              0.999997  0.188795
# 279          0.999988     0.996219              0.999997  0.194608
# 280          0.999988     0.999997              0.999997  0.237965
# 281          0.950560     0.914661              0.967070  0.002388
# 282          0.950560     0.904830              0.967070  0.009220
# 283          0.993239     0.983381              0.999997  0.151931
# 284          0.954952     0.931419              0.967369  0.025804
# 285          0.993239     0.989353              0.999997  0.233340
# 286          0.950560     0.917109              0.967070  0.032145
# 287          0.950560     0.923490              0.967070  0.041878
# 288          0.950560     0.924598              0.967070  0.052340
# 289          0.975072     0.960719              0.983989  0.121370
# 290          0.962710     0.941178              0.974086  0.082158
# 291          0.950560     0.924535              0.967070  0.066634
# 292          0.975563     0.964044              0.983990  0.141002
# 293          0.966139     0.959029              0.983989  0.134316
# 294          0.966428     0.950301              0.980102  0.160331
# 295          0.950560     0.930254              0.967369  0.114088
#
#      Combined Score                                              Genes
# 0          1.737638                             BMP1;TLL2;PCOLCE;LOXL2
# 1          1.034297  SPARC;COL16A1;BMP1;COL6A1;ADAM10;TLL2;FBLN1;PC...
# 2          1.003436                      BMP1;COL6A1;TLL2;PCOLCE;LOXL2
# 3          0.992206                    BMP1;COL16A1;COL6A1;TLL2;PCOLCE
# 4          0.986834              BMP1;COL16A1;COL6A1;TLL2;PCOLCE;LOXL2
# 5          0.947122                                   FBLN1;BMP7;LOXL2
# 6          0.831460                    DEPDC7;RASGRF2;ARHGAP1;ARHGAP28
# 7          0.689232                                KERA;THBS2;ADAMTS10
# 8          0.598396                                               KERA
# 9          0.590239                                  CNTN6;CNTN1;SCN2B
# 10         0.583407                            SLC24A2;SLC38A5;SLC38A4
# 11         0.562617                           COL16A1;BMP1;ADAM10;TLL2
# 12         0.539049                                              CNTN1
# 13         0.528153                                             CHRNA3
# 14         0.524059                                            SLC24A2
# 15         0.502120                                             CHRNA3
# 16         0.493636                                               GLI2
# 17         0.491060                                             ADAM10
# 18         0.487871                                             ADAM10
# 19         0.480383       CNTN6;RASGRF2;COL6A1;CNTN1;ADAM10;NRG1;SCN2B
# 20         0.479016                                               ARSE
# 21         0.476758                                             CHRNA3
# 22         0.474863                                             ADAM10
# 23         0.470031                                             CHRNA3
# 24         0.469281                                             CHRNA3
# 25         0.467839                                             ADAM10
# 26         0.464030                                               NRG1
# 27         0.460786                                              SALL1
# 28         0.456843                                               NRG1
# 29         0.455519                                              CNTN6
# ..              ...                                                ...
# 266        0.005774                                              CETN2
# 267        0.004764  CPB2;ST6GAL2;CETN2;COPZ2;CD59;IGFBP6;THBS2;ARS...
# 268        0.003670                                       RASGRF2;NRG1
# 269        0.002278                                       RASGRF2;NRG1
# 270        0.001780                                              CETN2
# 271        0.001739  NPFFR2;STAT5A;CX3CR1;FST;GPR32;RASGRF2;ARHGAP1...
# 272        0.001102                                       RASGRF2;NRG1
# 273        0.000496                                       RASGRF2;NRG1
# 274        0.000373                                       RASGRF2;NRG1
# 275        0.000070                                       RASGRF2;NRG1
# 276        0.000035                                       RASGRF2;NRG1
# 277       -0.000001                                       NUAK1;ZNF689
# 278       -0.000002       NSDHL;LIPC;BMP1;HS3ST3A1;RBP2;FASN;KERA;ARSE
# 279       -0.000002                                               NRG1
# 280       -0.000003                                       NUAK1;ZNF689
# 281       -0.000121                                       RASGRF2;NRG1
# 282       -0.000467                                       RASGRF2;NRG1
# 283       -0.001031                                              CETN2
# 284       -0.001189                                       RASGRF2;NRG1
# 285       -0.001583          STAT5A;RASGRF2;TNFSF11;NRG1;CD59;CCR6;C8B
# 286       -0.001630                                              NUAK1
# 287       -0.002123                                       RASGRF2;NRG1
# 288       -0.002654                                       RASGRF2;NRG1
# 289       -0.003064                                       RASGRF2;NRG1
# 290       -0.003122                                       RASGRF2;NRG1
# 291       -0.003379                    NPFFR2;GPR32;RASGRF2;OR6M1;CCR6
# 292       -0.003488                                              CETN2
# 293       -0.004627        NPFFR2;CX3CR1;GPR32;RASGRF2;OR6M1;NRG1;CCR6
# 294       -0.005475                                              OR6M1
# 295       -0.005785                         RASGRF2;NRG1;CD59;CCR6;C8B
#
# [296 rows x 9 columns]

# %%
from IPython.display import HTML

# %%
# Out:
# <div class="card" style="width: 350px">
#     <div class="card-content" id="content">
#         <p>The GSEA enrichment analysis</p>
#     </div>
#     <div class="card-tabs">
#         <ul class="tabs">
#             <li class="tab"><a class="active" href="#card_element-1497257921.869053-0">table</a></li>
#         </ul>
#     </div>
#     <div class="card-content grey lighten-4">
#         <div id="card_element-1497257921.869053-0"><div class="row">
#     <div class="switch col s6" id="switch0">
#         <label>
#             Show All: &nbsp;&nbsp; Off
#                 <input type="checkbox" id="switch">
#                 <span class="lever"></span>
#             On
#         </label>
#     </div>
# </div>
# <div class="row">
#     <div class="input-field col s6">
#         <label class="active" for="select">Sort</label>
#         <select id="sort">
#             <option value="Default">pvalue</option>
#             <option value="name">name</option>
#
#         </select>
#     </div>
# </div>
# <div class="row">
#     <div class="input-field col s6">
#         <label class="active" for="tests">display percent</label>
#         <input type="range" id="percent" min="0.1" max="1" step="0.01"/>
#     </div>
# </div>
# </div>
#     </div>
# </div>

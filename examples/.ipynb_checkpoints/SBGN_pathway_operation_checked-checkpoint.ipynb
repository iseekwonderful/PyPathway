# %%
from pypathway import *

# %%
path = PublicDatabase.search_reactome("jak")[0].load()

# %%
# briefly screen pathway
path
# Out:
# class: sbgn, id: root, type: None, external_id: None

# %%
# detailly summary pathway
print(path.summary())
# Out:
# class: sbgn, props: option: None, version: , attrs: <xml.sax.xmlreader.AttributesImpl object at 0x10c30bb70>, core_implement: SBGN, id: root
# ....class: map, props: language: process description, option: None, core_implement: SBGN
# ........class: arc, props: target: reactionVertex11025352, option: None, type: consumption, core_implement: SBGN, id: edge11025325, source: entityVertex11025339
# ............class: start, Props: core_implement: SBGN, x: 1057.5, y: 822.0, option: None
# ............class: end, Props: core_implement: SBGN, x: 1401.0, y: 858.0, option: None
# ........class: arc, props: target: reactionVertex11025356, option: None, type: consumption, core_implement: SBGN, id: edge11025332, source: entityVertex11025318
# ............class: start, Props: core_implement: SBGN, x: 1945.5, y: 793.5, option: None
# ............class: end, Props: core_implement: SBGN, x: 2508.0, y: 777.0, option: None
# ...

# %%
# get element by class
path.get_element_by_class("glyph")
# Out:
# [class: glyph, id: compartmentVertex701016792779, type: compartment, external_id: [],
#  class: glyph, id: compartmentVertex70101918181, type: compartment, external_id: [],
#  class: glyph, id: entityVertex11025318, type: unspecified entity, external_id: [{'Reactome Database ID Release 58': '6783659'}, {'Reactome': 'R-HSA-6783659'}],
#  class: glyph, id: entityVertex11025319, type: complex, external_id: [{'Reactome Database ID Release 58': '449948'}, {'Reactome': 'R-HSA-449948'}],
#  class: glyph, id: entityVertex11025320, type: macromolecule, external_id: [{'Reactome Database ID Release 58': '447097'}, {'Reactome': 'R-HSA-447097'}],
#  class: glyph, id: entityVertex11025321, type: macromolecule, external_id: [{'Reactome Database ID Release 58': '5696441'}, {'Reactome': 'R-HSA-5696441'}],
#  class: glyph, id: entityVertex11025322, type: macromolecule, external_id: [{'Reactome Database ID Release 58': '447212'}, {'Reactome': 'R-HSA-447212'}],
# ...

# %%
# get element by type
path.get_element_by_type("complex")
# Out:
# [class: glyph, id: entityVertex11025319, type: complex, external_id: [{'Reactome Database ID Release 58': '449948'}, {'Reactome': 'R-HSA-449948'}],
#  class: glyph, id: entityVertex11025326, type: complex, external_id: [{'Reactome Database ID Release 58': '448442'}, {'Reactome': 'R-HSA-448442'}],
#  class: glyph, id: entityVertex11025328, type: complex, external_id: [{'Reactome Database ID Release 58': '6783635'}, {'Reactome': 'R-HSA-6783635'}],
#  class: glyph, id: entityVertex11025329, type: complex, external_id: [{'Reactome Database ID Release 58': '6784198'}, {'Reactome': 'R-HSA-6784198'}],
#  class: glyph, id: entityVertex11025330, type: complex, external_id: [{'Reactome Database ID Release 58': '6783544'}, {'Reactome': 'R-HSA-6783544'}],
#  class: glyph, id: entityVertex11025333, type: complex, external_id: [{'Reactome Database ID Release 58': '6784202'}, {'Reactome': 'R-HSA-6784202'}],
# ...

# %%
path.get_element_by_label("IL12A")
# the node's graphic name is in child label.
# Out:
# [class: glyph, id: entityVertex11025322, type: macromolecule, external_id: [{'Reactome Database ID Release 58': '447212'}, {'Reactome': 'R-HSA-447212'}],
#  class: glyph, id: entityVertex11165228, type: macromolecule, external_id: [{'Reactome Database ID Release 58': '447212'}, {'Reactome': 'R-HSA-447212'}],
#  class: glyph, id: entityVertex11025365IL12A, type: macromolecule, external_id: [],
#  class: glyph, id: entityVertex11025369IL12A, type: macromolecule, external_id: [],
#  class: glyph, id: entityVertex11165254IL12A, type: macromolecule, external_id: [],
#  class: glyph, id: entityVertex11165257IL12A, type: macromolecule, external_id: []]

# %%
# or you can use path.label to get all the nodes with desire label
path.IL12A
# Out:
# [class: glyph, id: entityVertex11025322, type: macromolecule, external_id: [{'Reactome Database ID Release 58': '447212'}, {'Reactome': 'R-HSA-447212'}],
#  class: glyph, id: entityVertex11165228, type: macromolecule, external_id: [{'Reactome Database ID Release 58': '447212'}, {'Reactome': 'R-HSA-447212'}],
#  class: glyph, id: entityVertex11025365IL12A, type: macromolecule, external_id: [],
#  class: glyph, id: entityVertex11025369IL12A, type: macromolecule, external_id: [],
#  class: glyph, id: entityVertex11165254IL12A, type: macromolecule, external_id: [],
#  class: glyph, id: entityVertex11165257IL12A, type: macromolecule, external_id: []]

# %%
# get pathway id by name.
path.get_element_by_id("edge11025325")
# Out:
# [class: arc, id: edge11025325, type: consumption, external_id: None]

# %%
path.get_element_by_oid("6809138")
# Out:
# [class: glyph, id: entityVertex11025369, type: complex, external_id: [{'Reactome Database ID Release 58': '6809138'}, {'Reactome': 'R-HSA-6809138'}],
#  class: glyph, id: entityVertex11165257, type: complex, external_id: [{'Reactome Database ID Release 58': '6809138'}, {'Reactome': 'R-HSA-6809138'}]]

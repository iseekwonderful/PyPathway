# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

# %%
sys.path.append('/Users/sheep/PyPathway/')

# %%
from pypathway.analysis.network import Enrichnet, SPIA
from pypathway.utils import ColorectalCancer

# %%
geneset = ['LRRK2', 'PARK2', 'SNCA', 'APOE', 'PINK1', 'MAPT', 'GBA', 'COMT', 'UCHL1', 'MAOB', 'DRD2', 'CYP2D6', 'PARK7', 'SLC6A3', 'BDNF', 'NR4A2', 'GIGYF2', 'DRD3', 'GSTM1', 'MTHFR', 'PON1', 'GSTP1', 'NAT2', 'HFE', 'ATP13A2', 'IL1A', 'IL1B', 'MAOA', 'ND1', 'ABCB1', 'FGF20', 'GSTT1', 'FMR1', 'SLC6A4', 'TNF', 'SOD2', 'PITX3', 'ND3', 'NQO1', 'DRD4', 'LINGO1', 'SEMA5A', 'CYP2E1', 'ND2', 'ATXN3', 'NOS1', 'NOS2A', 'POLG', 'ATXN2', 'TBP', 'TFAM', 'TRNG', 'GSTO2', 'SERPINA3', 'DBH', 'ESR1', 'ESR2', 'PARK10', 'HTRA2', 'HTR2A', 'IL6', 'GSTO1', 'SNCAIP', 'BST1', 'TH', 'IL10', 'LMX1B', 'GSTM3', 'HNMT', 'FTL', 'GRN', 'GRIN2B', 'GSK3B', 'EPHX1', 'ACE', 'CYP1A1', 'CYP1A2', 'ND5', 'ATP6', 'COX2', 'NQO2', 'TRNQ', 'NEDD9', 'NUCKS1', 'CACNA1A', 'PRNP', 'USP40', 'CALB1', 'SNCG', 'TRNK', 'NDUFV2', 'NOS3', 'MSX1', 'COX1', 'ATP8', 'ASCL1', 'PARK11', 'LMX1A', 'MTR', 'ND4', 'CYTB', 'NUDT1', 'CYP1B1', 'ADRA2A', 'CST3', 'PACRG', 'CHRNA4', 'DRD5', 'ELAVL4', 'A2M', 'USP24', 'TOR1A', 'GCH1', 'GSTZ1', 'STH', 'FRAXA', 'FTH1', 'HMOX1', 'IL8', 'IL1RN', 'CAST', 'PDXK', 'UNC5C', 'CCK', 'CCKAR', 'CCKBR']

# %%
task = Enrichnet.run(geneset, pathdb='kegg')
# Out:
# checking:  done!
# checking:  processing...

# %%
task.plot
# Out:
# <div id="box1502374592349603" style="width: 100%; height: 0px;background-color: #ffffff">
#     <script>
#         var box = $("#box1502374592349603");
#         var father = box.parent();
# //        var grandfather = father.parent();
#         var thirdfather = father.parent().parent().parent();
#         thirdfather.children(".prompt").remove();
#         father.parent().children(".prompt").remove();
#         father.css("max-width", "100%");
#         box.css("margin-left", "5px");
#         var target = document.getElementById("box1502374592349603");
# //        var w = target.offsetWidth;
#         var w = thirdfather.outerWidth();
#         console.log(w);
#         target.style.height = w * 0.6 + "px";
#         box.append($("<iframe width='" + (parseInt(w) - 15).toString() + "'" +
#                 " height='" + w * 0.6 + "' src='assets/plot/plot_1502374592349603.html' " +
#                 "frameborder='0'></iframe>"))
#     </script>
# </div>

# %%
c = ColorectalCancer()

# %%
r = SPIA.run(de=c.deg, all=c.background)

# %%
r.table
# Out:
#                                            name         pNDE  pPERT  \
# 04510                            Focal adhesion  1.00919e-07  5e-06
# 05010                       Alzheimer's disease  2.50371e-11  0.222
# 04512                  ECM-receptor interaction  4.05857e-06  5e-06
# 05012                       Parkinson's disease  6.43572e-10  0.075
# 05200                        Pathways in cancer  4.19405e-05  0.007
# 03320                    PPAR signaling pathway  7.34632e-06  0.062
# 04360                             Axon guidance  1.79312e-05  0.137
# 04010                    MAPK signaling pathway  4.19588e-05  0.174
# 05016                      Huntington's disease  3.39073e-05  0.236
# 05222                    Small cell lung cancer   0.00697852  0.001
# 04666          Fc gamma R-mediated phagocytosis  4.57417e-05  0.215
# 04810          Regulation of actin cytoskeleton  0.000103382  0.405
# 05100    Bacterial invasion of epithelial cells  0.000362704  0.816
# 04724                     Glutamatergic synapse    0.0270076  0.016
# 05130     Pathogenic Escherichia coli infection    0.0141227  0.036
# 04310                     Wnt signaling pathway   0.00243769  0.296
# 05211                      Renal cell carcinoma   0.00968047  0.083
# 05202   Transcriptional misregulation in cancer   0.00767944   0.13
# 04012                    ErbB signaling pathway   0.00756775  0.135
# 04662         B cell receptor signaling pathway   0.00639066  0.196
# 05210                         Colorectal cancer    0.0824663   0.02
# 05150           Staphylococcus aureus infection    0.0540336  0.035
# 05132                      Salmonella infection   0.00294537  0.633
# 05144                                   Malaria   0.00251134      1
# 04330                   Notch signaling pathway   0.00435829  0.683
# 04530                            Tight junction   0.00443024  0.686
# 05322              Systemic lupus erythematosus     0.322139  0.009
# 04070     Phosphatidylinositol signaling system    0.0228198  0.144
# 04670      Leukocyte transendothelial migration    0.0121214  0.272
# 04540                              Gap junction   0.00641944  0.606
# ...                                         ...          ...    ...
# 04971                    Gastric acid secretion     0.255051   0.89
# 05221                    Acute myeloid leukemia     0.261295  0.897
# 04620      Toll-like receptor signaling pathway       0.2414  0.975
# 04140                   Regulation of autophagy     0.352341   0.69
# 05140                             Leishmaniasis     0.289817  0.863
# 05330                       Allograft rejection      0.86486  0.294
# 05320                Autoimmune thyroid disease     0.859233  0.303
# 04622     RIG-I-like receptor signaling pathway     0.840855  0.322
# 04350                TGF-beta signaling pathway     0.436466  0.666
# 04940                  Type I diabetes mellitus      0.71571  0.457
# 04730                      Long-term depression     0.505713  0.662
# 05332                 Graft-versus-host disease     0.949396   0.34
# 05162                                   Measles     0.938675  0.339
# 04962  Vasopressin-regulated water reabsorption     0.422817  0.791
# 04080   Neuroactive ligand-receptor interaction     0.999994  0.429
# 04920           Adipocytokine signaling pathway     0.523033   0.91
# 05203                      Viral carcinogenesis     0.648183  0.743
# 04340                Hedgehog signaling pathway     0.619739  0.975
# 04612       Antigen processing and presentation     0.882984  0.704
# 03018                           RNA degradation     0.952157      1
# 03460                    Fanconi anemia pathway            1      1
# 04623             Cytosolic DNA-sensing pathway     0.921192    0.9
# 04950      Maturity onset diabetes of the young     0.907831      1
# 04744                         Phototransduction     0.983284      1
# 04742                        Taste transduction     0.971296  0.758
# 04740                    Olfactory transduction     0.999968  0.941
# 04110                                Cell cycle     0.976167  0.702
# 03013                             RNA transport     0.987437      1
# 04514            Cell adhesion molecules (CAMs)   6.4188e-05    NaN
# 04520                         Adherens junction  0.000258273    NaN
#
#                 pG        pGfdr      pNDEfdr         pGbf     status
# 04510  1.47922e-11  2.02653e-09  4.67589e-06  2.02653e-09  Activated
# 05010  1.49604e-10  1.02479e-08  3.48016e-09  2.04958e-08  Inhibited
# 04512  5.19918e-10  2.37429e-08  0.000141035  7.12288e-08  Activated

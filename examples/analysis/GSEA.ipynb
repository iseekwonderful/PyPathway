# %% [markdown]
# # GSEA
# Implemented via GSEApy
# > Github: https://github.com/BioNinja/GSEApy

# %%
from pypathway import GSEA
import pandas as pd

# %%
# load the cls file
phenoA, phenoB, class_vector = GSEA.parse_class_vector("./data/GSE4107.cls")

# %%
# load the table
gene_exp = pd.read_excel("./data/GSE4107.xlsx")

# %%
r = GSEA.run(data=gene_exp[:1000], gmt="KEGG_2016", cls=class_vector)

# %%
r.table.sort_values("fdr")
# Out:
#                                                           es       nes  \
# Term
# Valine, leucine and isoleucine degradation_Homo... -0.665547 -1.757778
# Longevity regulating pathway - mammal_Homo sapi...  0.557222  1.414885
# Adrenergic signaling in cardiomyocytes_Homo sap...  0.582017  1.433929
# Oocyte meiosis_Homo sapiens_hsa04114                0.541513  1.461276
# Vascular smooth muscle contraction_Homo sapiens...  0.606684  1.482789
# Fatty acid degradation_Homo sapiens_hsa00071       -0.457804 -1.510427
# Calcium signaling pathway_Homo sapiens_hsa04020     0.522235  1.351096
# ABC transporters_Homo sapiens_hsa02010             -0.404447 -1.273776
# Peroxisome_Homo sapiens_hsa04146                   -0.534001 -1.437382
# cGMP-PKG signaling pathway_Homo sapiens_hsa04022    0.543966  1.482876
# Glycerolipid metabolism_Homo sapiens_hsa00561      -0.371547 -1.278422
# Carbon metabolism_Homo sapiens_hsa01200            -0.453609 -1.312282
# Rap1 signaling pathway_Homo sapiens_hsa04015        0.456596  1.195919
# Regulation of lipolysis in adipocytes_Homo sapi...  0.446178  1.172828
# cAMP signaling pathway_Homo sapiens_hsa04024        0.459762  1.265664
# Fatty acid metabolism_Homo sapiens_hsa01212        -0.457701 -1.348989
# Phospholipase D signaling pathway_Homo sapiens_...  0.464774  1.205908
# HTLV-I infection_Homo sapiens_hsa05166              0.549480  1.514222
# Glycolysis / Gluconeogenesis_Homo sapiens_hsa00010 -0.377724 -1.166247
# Purine metabolism_Homo sapiens_hsa00230             0.379754  1.212006
# Bile secretion_Homo sapiens_hsa04976               -0.398991 -1.102568
# Neuroactive ligand-receptor interaction_Homo sa...  0.403062  1.038409
# Progesterone-mediated oocyte maturation_Homo sa...  0.558664  1.551732
#
#                                                         pval       fdr  \
# Term
# Valine, leucine and isoleucine degradation_Homo...  0.000000  0.032914
# Longevity regulating pathway - mammal_Homo sapi...  0.114786  0.197642
# Adrenergic signaling in cardiomyocytes_Homo sap...  0.082243  0.202675
# Oocyte meiosis_Homo sapiens_hsa04114                0.089147  0.203546
# Vascular smooth muscle contraction_Homo sapiens...  0.032692  0.214649
# Fatty acid degradation_Homo sapiens_hsa00071        0.035928  0.242842
# Calcium signaling pathway_Homo sapiens_hsa04020     0.126679  0.243150
# ABC transporters_Homo sapiens_hsa02010              0.131631  0.255744
# Peroxisome_Homo sapiens_hsa04146                    0.118110  0.265721
# cGMP-PKG signaling pathway_Homo sapiens_hsa04022    0.065543  0.286199
# Glycerolipid metabolism_Homo sapiens_hsa00561       0.160714  0.292481
# Carbon metabolism_Homo sapiens_hsa01200             0.214425  0.305058
# Rap1 signaling pathway_Homo sapiens_hsa04015        0.233463  0.305398
# Regulation of lipolysis in adipocytes_Homo sapi...  0.312500  0.307392
# cAMP signaling pathway_Homo sapiens_hsa04024        0.225141  0.314040
# Fatty acid metabolism_Homo sapiens_hsa01212         0.130346  0.322317
# Phospholipase D signaling pathway_Homo sapiens_...  0.289524  0.322797
# HTLV-I infection_Homo sapiens_hsa05166              0.072106  0.328357
# Glycolysis / Gluconeogenesis_Homo sapiens_hsa00010  0.295050  0.332453
# Purine metabolism_Homo sapiens_hsa00230             0.234615  0.347358
# Bile secretion_Homo sapiens_hsa04976                0.290650  0.356971
# Neuroactive ligand-receptor interaction_Homo sa...  0.434185  0.428450
# Progesterone-mediated oocyte maturation_Homo sa...  0.049808  0.492832
#
#                                                     gene_set_size  \
# Term
# Valine, leucine and isoleucine degradation_Homo...             48
# Longevity regulating pathway - mammal_Homo sapi...             94
# Adrenergic signaling in cardiomyocytes_Homo sap...            148
# Oocyte meiosis_Homo sapiens_hsa04114                          123
# Vascular smooth muscle contraction_Homo sapiens...            120
# Fatty acid degradation_Homo sapiens_hsa00071                   44
# Calcium signaling pathway_Homo sapiens_hsa04020               180
# ABC transporters_Homo sapiens_hsa02010                         44
# Peroxisome_Homo sapiens_hsa04146                               83
# cGMP-PKG signaling pathway_Homo sapiens_hsa04022              167
# Glycerolipid metabolism_Homo sapiens_hsa00561                  59
# Carbon metabolism_Homo sapiens_hsa01200                       113
# Rap1 signaling pathway_Homo sapiens_hsa04015                  211
# Regulation of lipolysis in adipocytes_Homo sapi...             56
# cAMP signaling pathway_Homo sapiens_hsa04024                  199
# Fatty acid metabolism_Homo sapiens_hsa01212                    48
# Phospholipase D signaling pathway_Homo sapiens_...            144
# HTLV-I infection_Homo sapiens_hsa05166                        258
# Glycolysis / Gluconeogenesis_Homo sapiens_hsa00010             67
# Purine metabolism_Homo sapiens_hsa00230                       176
# Bile secretion_Homo sapiens_hsa04976                           71
# Neuroactive ligand-receptor interaction_Homo sa...            277
# Progesterone-mediated oocyte maturation_Homo sa...             98
#
#                                                     matched_size  \
# Term
# Valine, leucine and isoleucine degradation_Homo...            18
# Longevity regulating pathway - mammal_Homo sapi...            16
# Adrenergic signaling in cardiomyocytes_Homo sap...            20
# Oocyte meiosis_Homo sapiens_hsa04114                          17
# Vascular smooth muscle contraction_Homo sapiens...            17
# Fatty acid degradation_Homo sapiens_hsa00071                  30
# Calcium signaling pathway_Homo sapiens_hsa04020               16
# ABC transporters_Homo sapiens_hsa02010                        40
# Peroxisome_Homo sapiens_hsa04146                              17
# cGMP-PKG signaling pathway_Homo sapiens_hsa04022              24
# Glycerolipid metabolism_Homo sapiens_hsa00561                 16
# Carbon metabolism_Homo sapiens_hsa01200                       16
# Rap1 signaling pathway_Homo sapiens_hsa04015                  18
# Regulation of lipolysis in adipocytes_Homo sapi...            17
# cAMP signaling pathway_Homo sapiens_hsa04024                  22
# Fatty acid metabolism_Homo sapiens_hsa01212                   19
# Phospholipase D signaling pathway_Homo sapiens_...            18
# HTLV-I infection_Homo sapiens_hsa05166                        19
# Glycolysis / Gluconeogenesis_Homo sapiens_hsa00010            23
# Purine metabolism_Homo sapiens_hsa00230                       29
# Bile secretion_Homo sapiens_hsa04976                          18
# Neuroactive ligand-receptor interaction_Homo sa...            16
# Progesterone-mediated oocyte maturation_Homo sa...            20
#
#                                                                                                 genes
# Term
# Valine, leucine and isoleucine degradation_Homo...  ALDH1B1,AGXT2,ALDH9A1,ACAT1,ALDH2,AACS,ALDH7A1...
# Longevity regulating pathway - mammal_Homo sapi...  ADIPOQ,ADCY4,ADCY5,ADCY2,AKT3,ADCY8,ADCY7,ADCY...
# Adrenergic signaling in cardiomyocytes_Homo sap...  AGTR1,ADCY4,ADCY5,ADRA1B,ADRB2,ADRB1,ADCY2,AKT...
# Oocyte meiosis_Homo sapiens_hsa04114                ADCY4,ADCY5,ADCY2,ADCY8,ANAPC13,ADCY7,ANAPC11,...
# Vascular smooth muscle contraction_Homo sapiens...  ACTA2,AGTR1,ACTG2,ADCY4,ADCY5,ADRA1B,ADCY2,ADC...
# Fatty acid degradation_Homo sapiens_hsa00071        ADH1B,ACADL,ACSBG1,ACSL6,ADH7,ACSL4,ALDH1B1,AD...
# Calcium signaling pathway_Homo sapiens_hsa04020     AGTR1,ADCY4,ADRA1B,ADRB2,ADRB1,ADCY2,ADCY8,ADC...
# ABC transporters_Homo sapiens_hsa02010              ABCA9,ABCA3,ABCB4,ABCC9,ABCD1,ABCD2,ABCC1,ABCA...
# Peroxisome_Homo sapiens_hsa04146                    ACSL6,ABCD1,ABCD2,ACSL4,ACSL1,ACOX2,AGXT,ACSL3...
# cGMP-PKG signaling pathway_Homo sapiens_hsa04022    AGTR1,ADCY4,ADCY5,ADRA1B,ADRB2,ADRB1,ADCY2,AKT...
# Glycerolipid metabolism_Homo sapiens_hsa00561       AGPAT4,AKR1B1,AGPAT1,ALDH1B1,AGPAT6,AGK,ALDH9A...
# Carbon metabolism_Homo sapiens_hsa01200             ACSS1,ALDOC,ADPGK,ADH5,ACO2,ACO1,ACAT1,AGXT,AL...
# Rap1 signaling pathway_Homo sapiens_hsa04015        ADCY4,ADCY5,ANGPT2,ANGPT1,ADCY2,AKT3,ADCY8,ADC...
# Regulation of lipolysis in adipocytes_Homo sapi...  ADCY4,ADCY5,ADRB2,ADRB1,ADCY2,AKT3,ADCY8,ADCY7...
# cAMP signaling pathway_Homo sapiens_hsa04024        ADCY4,ADCY5,ADCY10,ADRB2,ADRB1,ADCY2,AKT3,AMH,...
# Fatty acid metabolism_Homo sapiens_hsa01212         ACADL,ACSBG1,ACSL6,ACSL4,ACSL1,ACADVL,ACAT1,AC...
# Phospholipase D signaling pathway_Homo sapiens_...  AGTR1,AGPAT4,ADCY4,ADCY5,ADCY2,AKT3,ADCY8,ADCY...
# HTLV-I infection_Homo sapiens_hsa05166              ADCY4,ADCY5,ADCY2,AKT3,ADCY8,ADCY7,ANAPC11,ADC...
# Glycolysis / Gluconeogenesis_Homo sapiens_hsa00010  ADH1B,ADH7,ACSS1,ALDOC,ALDH3B2,ADPGK,ALDH1B1,A...
# Purine metabolism_Homo sapiens_hsa00230             ADCY4,ADCY5,ADA,AK5,ADCY10,ALLC,ADCY2,ADCY8,AD...
# Bile secretion_Homo sapiens_hsa04976                ADCY4,ADCY5,ABCB4,ADCY2,ADCY8,ADCY7,ADCY3,ADCY...
# Neuroactive ligand-receptor interaction_Homo sa...  AGTR1,ADRA1B,ADRB2,ADRB1,ADCYAP1R1,ADRA2C,AGTR...
# Progesterone-mediated oocyte maturation_Homo sa...  ADCY4,ADCY5,ADCY2,AKT3,ADCY8,ANAPC13,ADCY7,ANA...

# %%
r.plot()
# Out:
# <div id="box1513492687363121" style="width: 100%; height: 0px;background-color: #ffffff">
#     <script>
#         var box = $("#box1513492687363121");
#         var father = box.parent();
#         var thirdfather = father.parent().parent().parent();
#         thirdfather.children(".prompt").remove();
#         father.parent().children(".prompt").remove();
#         father.css("max-width", "100%");
#         box.css("margin-left", "5px");
#         var target = document.getElementById("box1513492687363121");
#         var w = thirdfather.outerWidth();
#         console.log(w);
#         target.style.height = w * 0.6 + "px";
#         box.append($("<iframe width='" + (parseInt(w) - 15).toString() + "'" +
#                 " height='" + (w * 0.6 - 5) + "' src='assets/plot/plot_1513492687363121.html' " +
#                 "frameborder='0'></iframe>"))
#     </script>
# </div>

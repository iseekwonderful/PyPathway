# %% [markdown]
# # GSEA
# Implemented via GSEApy
# > Github: https://github.com/BioNinja/GSEApy

# %%
from pypathway import GSEA
import pandas as pd

# %%
# load the cls file
phenoA, phenoB, class_vector = GSEA.parse_class_vector("./data/GSE4107.cls")

# %%
# load the table
gene_exp = pd.read_excel("./data/GSE4107.xlsx")

# %%
r = GSEA.run(data=gene_exp[:1000], gmt="KEGG_2016", cls=class_vector)

# %%
r.table.sort_values("es")
# Out:
#                                                           es       nes  \
# Term
# Valine, leucine and isoleucine degradation_Homo... -0.836357 -1.826013
# Glycerolipid metabolism_Homo sapiens_hsa00561      -0.674108 -1.892257
# Peroxisome_Homo sapiens_hsa04146                   -0.672286 -1.643600
# Fatty acid degradation_Homo sapiens_hsa00071       -0.659410 -1.862730
# Fatty acid metabolism_Homo sapiens_hsa01212        -0.631014 -1.610046
# Carbon metabolism_Homo sapiens_hsa01200            -0.573840 -1.511835
# Glycolysis / Gluconeogenesis_Homo sapiens_hsa00010 -0.541174 -1.649671
# Metabolic pathways_Homo sapiens_hsa01100           -0.474343 -1.717200
# PPAR signaling pathway_Homo sapiens_hsa03320       -0.402356 -1.118456
# ABC transporters_Homo sapiens_hsa02010             -0.396604 -1.409907
# Bile secretion_Homo sapiens_hsa04976               -0.347119 -1.078285
# Purine metabolism_Homo sapiens_hsa00230             0.276614  0.954087
# cAMP signaling pathway_Homo sapiens_hsa04024        0.356293  1.022952
# Adipocytokine signaling pathway_Homo sapiens_hs...  0.356350  1.040501
# Neuroactive ligand-receptor interaction_Homo sa...  0.379797  1.093517
# Phospholipase D signaling pathway_Homo sapiens_...  0.383465  1.064518
# Regulation of lipolysis in adipocytes_Homo sapi...  0.434352  1.110520
# Rap1 signaling pathway_Homo sapiens_hsa04015        0.444657  1.215651
# Longevity regulating pathway - mammal_Homo sapi...  0.463505  1.245303
# Oocyte meiosis_Homo sapiens_hsa04114                0.470405  1.241000
# Salivary secretion_Homo sapiens_hsa04970            0.491192  1.203798
# cGMP-PKG signaling pathway_Homo sapiens_hsa04022    0.507690  1.436179
# Calcium signaling pathway_Homo sapiens_hsa04020     0.510269  1.332034
# Vascular smooth muscle contraction_Homo sapiens...  0.511103  1.408130
# HTLV-I infection_Homo sapiens_hsa05166              0.517866  1.354221
# Progesterone-mediated oocyte maturation_Homo sa...  0.531081  1.406097
# Adrenergic signaling in cardiomyocytes_Homo sap...  0.586728  1.529954
#
#                                                         pval       fdr  \
# Term
# Valine, leucine and isoleucine degradation_Homo...  0.000000  0.006378
# Glycerolipid metabolism_Homo sapiens_hsa00561       0.000000  0.004159
# Peroxisome_Homo sapiens_hsa04146                    0.015686  0.033414
# Fatty acid degradation_Homo sapiens_hsa00071        0.000000  0.004159
# Fatty acid metabolism_Homo sapiens_hsa01212         0.021484  0.041238
# Carbon metabolism_Homo sapiens_hsa01200             0.045187  0.074454
# Glycolysis / Gluconeogenesis_Homo sapiens_hsa00010  0.020952  0.037601
# Metabolic pathways_Homo sapiens_hsa01100            0.009597  0.021213
# PPAR signaling pathway_Homo sapiens_hsa03320        0.305284  0.368691
# ABC transporters_Homo sapiens_hsa02010              0.064030  0.122379
# Bile secretion_Homo sapiens_hsa04976                0.331992  0.378583
# Purine metabolism_Homo sapiens_hsa00230             0.533708  0.524643
# cAMP signaling pathway_Homo sapiens_hsa04024        0.446927  0.472362
# Adipocytokine signaling pathway_Homo sapiens_hs...  0.407692  0.482626
# Neuroactive ligand-receptor interaction_Homo sa...  0.323944  0.480898
# Phospholipase D signaling pathway_Homo sapiens_...  0.389610  0.488037
# Regulation of lipolysis in adipocytes_Homo sapi...  0.362069  0.497588
# Rap1 signaling pathway_Homo sapiens_hsa04015        0.224490  0.426347
# Longevity regulating pathway - mammal_Homo sapi...  0.201479  0.488931
# Oocyte meiosis_Homo sapiens_hsa04114                0.215116  0.434928
# Salivary secretion_Homo sapiens_hsa04970            0.254369  0.400784
# cGMP-PKG signaling pathway_Homo sapiens_hsa04022    0.070209  0.701459
# Calcium signaling pathway_Homo sapiens_hsa04020     0.142045  0.407636
# Vascular smooth muscle contraction_Homo sapiens...  0.101504  0.556289
# HTLV-I infection_Homo sapiens_hsa05166              0.152805  0.444102
# Progesterone-mediated oocyte maturation_Homo sa...  0.115830  0.421863
# Adrenergic signaling in cardiomyocytes_Homo sap...  0.057514  0.723525
#
#                                                     geneset_size  \
# Term
# Valine, leucine and isoleucine degradation_Homo...            48
# Glycerolipid metabolism_Homo sapiens_hsa00561                 59
# Peroxisome_Homo sapiens_hsa04146                              83
# Fatty acid degradation_Homo sapiens_hsa00071                  44
# Fatty acid metabolism_Homo sapiens_hsa01212                   48
# Carbon metabolism_Homo sapiens_hsa01200                      113
# Glycolysis / Gluconeogenesis_Homo sapiens_hsa00010            67
# Metabolic pathways_Homo sapiens_hsa01100                    1239
# PPAR signaling pathway_Homo sapiens_hsa03320                  69
# ABC transporters_Homo sapiens_hsa02010                        44
# Bile secretion_Homo sapiens_hsa04976                          71
# Purine metabolism_Homo sapiens_hsa00230                      176
# cAMP signaling pathway_Homo sapiens_hsa04024                 199
# Adipocytokine signaling pathway_Homo sapiens_hs...            70
# Neuroactive ligand-receptor interaction_Homo sa...           277
# Phospholipase D signaling pathway_Homo sapiens_...           144
# Regulation of lipolysis in adipocytes_Homo sapi...            56
# Rap1 signaling pathway_Homo sapiens_hsa04015                 211
# Longevity regulating pathway - mammal_Homo sapi...            94
# Oocyte meiosis_Homo sapiens_hsa04114                         123
# Salivary secretion_Homo sapiens_hsa04970                      89
# cGMP-PKG signaling pathway_Homo sapiens_hsa04022             167
# Calcium signaling pathway_Homo sapiens_hsa04020              180
# Vascular smooth muscle contraction_Homo sapiens...           120
# HTLV-I infection_Homo sapiens_hsa05166                       258
# Progesterone-mediated oocyte maturation_Homo sa...            98
# Adrenergic signaling in cardiomyocytes_Homo sap...           148
#
#                                                     matched_size  \
# Term
# Valine, leucine and isoleucine degradation_Homo...            18
# Glycerolipid metabolism_Homo sapiens_hsa00561                 16
# Peroxisome_Homo sapiens_hsa04146                              17
# Fatty acid degradation_Homo sapiens_hsa00071                  30
# Fatty acid metabolism_Homo sapiens_hsa01212                   19
# Carbon metabolism_Homo sapiens_hsa01200                       16
# Glycolysis / Gluconeogenesis_Homo sapiens_hsa00010            23
# Metabolic pathways_Homo sapiens_hsa01100                     146
# PPAR signaling pathway_Homo sapiens_hsa03320                  15
# ABC transporters_Homo sapiens_hsa02010                        40
# Bile secretion_Homo sapiens_hsa04976                          18
# Purine metabolism_Homo sapiens_hsa00230                       29
# cAMP signaling pathway_Homo sapiens_hsa04024                  22
# Adipocytokine signaling pathway_Homo sapiens_hs...            15
# Neuroactive ligand-receptor interaction_Homo sa...            16
# Phospholipase D signaling pathway_Homo sapiens_...            18
# Regulation of lipolysis in adipocytes_Homo sapi...            17
# Rap1 signaling pathway_Homo sapiens_hsa04015                  18
# Longevity regulating pathway - mammal_Homo sapi...            16
# Oocyte meiosis_Homo sapiens_hsa04114                          17
# Salivary secretion_Homo sapiens_hsa04970                      15
# cGMP-PKG signaling pathway_Homo sapiens_hsa04022              24
# Calcium signaling pathway_Homo sapiens_hsa04020               16
# Vascular smooth muscle contraction_Homo sapiens...            17
# HTLV-I infection_Homo sapiens_hsa05166                        19
# Progesterone-mediated oocyte maturation_Homo sa...            20
# Adrenergic signaling in cardiomyocytes_Homo sap...            20
#
#                                                                                                 genes
# Term
# Valine, leucine and isoleucine degradation_Homo...  AAMDC,AKAP8,ANKRD34C,AKAP9,AMACR,ADH1A,ADAM18,...
# Glycerolipid metabolism_Homo sapiens_hsa00561       ACTG2,ANKRD34A,AADAT,AAMDC,AK054988,ABCB5,AJ01...
# Peroxisome_Homo sapiens_hsa04146                    AADACL2,AC087501.1,ADAMTS15,ALDH1B1,ACVRL1,AF5...
# Fatty acid degradation_Homo sapiens_hsa00071        AHNAK2,AADACL2,ALOX5,ANXA2R,AK054708,ADAMTS15,...
# Fatty acid metabolism_Homo sapiens_hsa01212         AADACL2,ALOX5,ANXA2R,ADAMTS15,ACVRL1,ADRA1A,AN...
# Carbon metabolism_Homo sapiens_hsa01200             AC104667.3,ACAP1,AK054708,ADCYAP1R1,ANP32A,AF5...
# Glycolysis / Gluconeogenesis_Homo sapiens_hsa00010  AHNAK2,AC104667.3,ACAP1,AK054708,ADCYAP1R1,AAM...
# Metabolic pathways_Homo sapiens_hsa01100            AHNAK2,ANKS1B,AGPAT4,ANKRD35,ACTG2,ADCY5,ANKRD...
# PPAR signaling pathway_Homo sapiens_hsa03320        AOC3,ADRA1B,AADACL2,ALOX5,ANXA2R,ADAMTS15,ACVR...
# ABC transporters_Homo sapiens_hsa02010              AIRE,ADAMTSL4,ANKDD1A,AKT3,ABI3,A2M,AC087501.1...
# Bile secretion_Homo sapiens_hsa04976                AF070581,ANK2,AC114752.3,AKT3,ACD,AK090844,AHN...
# Purine metabolism_Homo sapiens_hsa00230             ADCY5,AF070581,ANK2,AC114752.3,ANKRD6,ACKR1,AK...
# cAMP signaling pathway_Homo sapiens_hsa04024        AF070581,ANK2,AC114752.3,AGER,ACY1,AK5,ACTN1,A...
# Adipocytokine signaling pathway_Homo sapiens_hs...  AOC3,ACY1,AK5,AADACL2,ALOX5,AC007349.5,ABHD12B...
# Neuroactive ligand-receptor interaction_Homo sa...  A4GALT,AGER,ACTN1,AK096803,ANGPT4,AC018462.2,A...
# Phospholipase D signaling pathway_Homo sapiens_...  A4GALT,ANKRD34A,AF070581,ANK2,AC114752.3,ACY1,...
# Regulation of lipolysis in adipocytes_Homo sapi...  AF070581,ANK2,AC114752.3,AGER,ACY1,AK5,ACTN1,A...
# Rap1 signaling pathway_Homo sapiens_hsa04015        ACSS3,AF070581,ANK2,AC114752.3,ACY1,AK5,AC0055...
# Longevity regulating pathway - mammal_Homo sapi...  AOC3,AF070581,ANK2,AC114752.3,ACY1,AK5,AC00734...
# Oocyte meiosis_Homo sapiens_hsa04114                AF070581,ANK2,AC114752.3,ABCB4,ANXA10,AL831948...
# Salivary secretion_Homo sapiens_hsa04970            AF070581,ANK2,AC114752.3,AGER,ACTN1,AK096803,A...
# cGMP-PKG signaling pathway_Homo sapiens_hsa04022    A4GALT,AF070581,ANK2,AC114752.3,AGER,ACY1,AK5,...
# Calcium signaling pathway_Homo sapiens_hsa04020     A4GALT,AF070581,AC114752.3,AGER,ACTN1,AK096803...
# Vascular smooth muscle contraction_Homo sapiens...  ANXA1,A4GALT,ADCY4,AF070581,ANK2,AC114752.3,AK...
# HTLV-I infection_Homo sapiens_hsa05166              AF070581,ANK2,AC114752.3,ABCB4,ACY1,AK5,ANXA10...
# Progesterone-mediated oocyte maturation_Homo sa...  AF070581,ANK2,AC114752.3,ABCB4,ACY1,AK5,ANXA10...
# Adrenergic signaling in cardiomyocytes_Homo sap...  A4GALT,AF070581,ANK2,AC114752.3,AGER,ACY1,AK5,...

# %%
r.plot()
# Out:
# <div id="box1513492687363121" style="width: 100%; height: 0px;background-color: #ffffff">
#     <script>
#         var box = $("#box1513492687363121");
#         var father = box.parent();
#         var thirdfather = father.parent().parent().parent();
#         thirdfather.children(".prompt").remove();
#         father.parent().children(".prompt").remove();
#         father.css("max-width", "100%");
#         box.css("margin-left", "5px");
#         var target = document.getElementById("box1513492687363121");
#         var w = thirdfather.outerWidth();
#         console.log(w);
#         target.style.height = w * 0.6 + "px";
#         box.append($("<iframe width='" + (parseInt(w) - 15).toString() + "'" +
#                 " height='" + (w * 0.6 - 5) + "' src='assets/plot/plot_1513492687363121.html' " +
#                 "frameborder='0'></iframe>"))
#     </script>
# </div>
